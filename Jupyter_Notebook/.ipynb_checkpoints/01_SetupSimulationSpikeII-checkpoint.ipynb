# %% [markdown]
# # _**SpikeII GEOSPACE Setup Application**_
#
# **Author:** Concetta D'Amato
#
# ----

# %% [markdown]
# ## _**Experiment Setup**_

# %%
os.chdir(project_path+'/data/SpikeII/Img')

# %%
display(Image('Setup.png', width=700))

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors as cl 
from matplotlib import rc
import matplotlib.style as style 
import math
import xarray as xr
import warnings
import plotly.graph_objects as go
import plotly.express as px
from IPython.display import Image, display


import pandas as pd
warnings.filterwarnings('ignore')
style.available
style.use('seaborn-whitegrid')
#from GEOSPACE_Output import*

####### Plot settings #######
nice_fonts = {
    "legend.frameon": True, 
    "legend.fancybox": True, 
    "legend.facecolor": "white", 
    "axes.edgecolor": "0.8",
    "axes.linewidth": 0.6,
    "grid.linewidth":0.3,
    # Use LaTeX to write all text
    "text.usetex": False,
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 16,
    "font.size": 16,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
}
plt.rcParams.update(nice_fonts)

project_path = os.path.dirname(os.getcwd())

# %% [markdown]
# # _**Experiment Setup Spike Willow tree**_

# %% [markdown]
# ## **Simulazione 2802_01** -  _Java_SpikeIISpikeADE_2802_01_0000.nc_
# **Grid Geometry**
# **Grid_GEOSPACESpikeII_Solute_ADE_2802_01.nc_**
#
# gridSpikeII_2802_01.csv
#
# |Type      |eta    |K      |equationStateID     |parameterID    |
# |----------|-------|-------|--------------------|---------------|
# |L         |0      |80     |1                   |49             |
# |L         |-2.0   |10     |1                   |48             |
# |L         |-2.25  |nan    |nan                 |nan            |
#
#
# **Initial condition for suction, temperature and solute**
#
# icSpikeII_2802_01.csv
#
# |eta   |Psi0     |T0    |C0   |
# |------|---------|------|-----|
# |-0.25 |-1.14713 |293.15|0.0  |
# |-0.75 |-0.61021 |293.15|0.0  |
# |-1.25 |-0.89131 |293.15|0.0  |
# |-1.75 |-1.14713 |293.15|0.0  |
#
# **Initial condition for root density**
#
# icRootSpikeIImean.csv
#
# |eta   |Root0  |
# |------|-------|
# |-0.25 |0.205  |
# |-0.5  |0.299  |
# |-0.75 |0.209  |
# |-1.0  |0.179  |
# |-1.25 |0.180  |
# |-1.5  |0.190  |
# |-1.75 |0.201  |
# |-2.0  |0.183  |
#
#
# **Soil parameters for Van Genuchten**
#
# RichardsLysimeterSpikeII_VG_soluteade.csv
#
# | Symbol                 | Physical quantity                   | Unit              | Input                  |
# |------------------------|-------------------------------------|-------------------|------------------------|
# | $\theta_r$             |residual water content               | [-]               |thetaR                  |
# | $\theta_s$             |water content at saturation          | [-]               |thetaS                  |
# | $\alpha$               |Van Genuchten parameter              | [m$^{-1}$]        |alpha                   |
# | $n$                    |Van Genuchten parameter ($>1$)       | [-]               |n                       |
# | $m=$                   |Van Genuchten parameter              | [-]               |not required            |
# | $\alpha_{ss}$          |matrix compressibility               | []                |alphaSpecificStorage    |
# | $\beta{ss}$            |water compressibility                | []                |betaSpecificStorage     |
# | $K_s$                  |saturated hydraulic conductivity     | [m s$^{-1}$]      |Ks                      |
#
# **Soil parameters for water stress computation**
#
# | Symbol                 | Physical quantity                   | Unit              | Input                  |
# |------------------------|-------------------------------------|-------------------|------------------------|
# | $\theta_{WP}$          |water content at wilting point       | [-]               |thetaWP                 |
# | $\theta_{FC}$          |water content at field capacity      | [-]               |thetaFC                 |
#
# **Solute transport parameters**
#
# | Symbol                 | Physical quantity                   | Unit              | Input                  |
# |------------------------|-------------------------------------|-------------------|------------------------|
# | $D_w$                  |molecular diffusion                  | [m$^{2}$ s$^{-1}$]|molecularDiffusion      |
# | $\lambda_L$            |longitudinal dispersivity            | [m]               |longitudinalDispersivity|
#
#
# **Soil type 49**
#
# |thetaS |thetaR |thetaWP |thetaFC |n   |alpha |alphaSpecificStorage |betaSpecificStorage |Ks                   |molecularDiffusion |longitudinalDispersivity |
# |-------|-------|--------|--------|----|------|---------------------|--------------------|---------------------|-------------------|-------------------------|
# |0.3    |0.05   |0.0803  |0.205   |1.31|6     |1.0e-07              |4.4e-10             |3.472222222222222E-05|0.0                |0.007225                 |
#
# **Soil type 48**
#
# |thetaS |thetaR |thetaWP |thetaFC |n   |alpha |alphaSpecificStorage |betaSpecificStorage |Ks                   |molecularDiffusion |longitudinalDispersivity |
# |-------|-------|--------|--------|----|------|---------------------|--------------------|---------------------|-------------------|-------------------------|
# |0.3    |0.05   |0.0803  |0.22    |1.31|6     |1.0e-07              |4.4e-10             |3.472222222222222E-05|0.0                |0.007225                 |
#
# - etaR = -2.0
# - water_ponding_0 = -1.4
# - T_water_ponding_0 = 293.15
# - C_water_ponding_0 = 0
#
# Notebook grid creation name: 0_GEOSPACE1D_SpikeII_2802_01_Computational_grid.ipynb
#
# **Vegetation parameters**
#
# |Quantity\Variable       | Unit   | Input                   |
# |------------------------|--------|-------------------------|
# |canopy height           | [m]    |3.5                      |
# |leaf area index         | [-]    |SpikeII_LAI_6_2802_01.csv|
# |useRadiationStress      | [-]    |false                    |
# |useVDPStress            | [-]    |false                    |
# |useTemperatureStress    | [-]    |false                    |
# |useWaterStress          | [-]    |true                     |
# |etaR                    | [m]    |-2.0                     |
# |etaE                    | [m]    |-0.5                     |
# |representativeTsModel   | [-]    |RootWaterWeightedMethod  |
#
# - Top boundary condition: Top dirichlet
# - Bottom boundary condition : Bottom Free Dreinage
# - Radiation input from GEOframe (NetSpike_1.csv)
#
# ---
# Java file test name: TestGEOSPACEProsperoSoluteADE_Spike2802_01.java

# %% [markdown]
# <br>

# %% [markdown]
# # _**Experiment Setup Spike Bare Soil**_

# %% [markdown]
# ## **Simulazione 0203_01** -  Java_SpikeIISoilwaterstress0203_01_0000.nc_
# **Grid Geometry**
# **Grid_GEOSPACESpikeII_soil_2802_01.nc_**
#
# gridSpikeII_2802_01_soil.csv
#
# |Type      |eta    |K      |equationStateID     |parameterID    |
# |----------|-------|-------|--------------------|---------------|
# |L         |0      |80     |1                   |21             |
# |L         |-2.0   |10     |1                   |20             |
# |L         |-2.25  |nan    |nan                 |nan            |
#
#
# **Initial condition for suction, temperature and solute**
#
# icSpikeII_2802_01_soil.csv
#
# |eta   |Psi0     |T0    |
# |------|---------|------|
# |-0.25 |-1.14713 |293.15|
# |-0.75 |-0.61021 |293.15|
# |-1.25 |-0.89131 |293.15|
# |-1.75 |-1.14713 |293.15|
#
# **Initial condition for root density**
#
# icRootSpikeIImean.csv
#
# |eta   |Root0  |
# |------|-------|
# |-0.25 |0.205  |
# |-0.5  |0.299  |
# |-0.75 |0.209  |
# |-1.0  |0.179  |
# |-1.25 |0.180  |
# |-1.5  |0.190  |
# |-1.75 |0.201  |
# |-2.0  |0.183  |
#
#
# **Soil parameters for Van Genuchten**
#
# RichardsLysimeterSpikeII_VG.csv
#
# | Symbol                 | Physical quantity                   | Unit              | Input                  |
# |------------------------|-------------------------------------|-------------------|------------------------|
# | $\theta_r$             |residual water content               | [-]               |thetaR                  |
# | $\theta_s$             |water content at saturation          | [-]               |thetaS                  |
# | $\alpha$               |Van Genuchten parameter              | [m$^{-1}$]        |alpha                   |
# | $n$                    |Van Genuchten parameter ($>1$)       | [-]               |n                       |
# | $m=$                   |Van Genuchten parameter              | [-]               |not required            |
# | $\alpha_{ss}$          |matrix compressibility               | []                |alphaSpecificStorage    |
# | $\beta{ss}$            |water compressibility                | []                |betaSpecificStorage     |
# | $K_s$                  |saturated hydraulic conductivity     | [m s$^{-1}$]      |Ks                      |
#
# **Soil parameters for water stress computation**
#
# | Symbol                 | Physical quantity                   | Unit              | Input                  |
# |------------------------|-------------------------------------|-------------------|------------------------|
# | $\theta_{WP}$          |water content at wilting point       | [-]               |thetaWP                 |
# | $\theta_{FC}$          |water content at field capacity      | [-]               |thetaFC                 |
#
#
#
# **Soil type 21**
#
# |thetaS |thetaR |thetaWP |thetaFC |n   |alpha |alphaSpecificStorage |betaSpecificStorage |Ks                   |molecularDiffusion |longitudinalDispersivity |
# |-------|-------|--------|--------|----|------|---------------------|--------------------|---------------------|-------------------|-------------------------|
# |0.3    |0.05   |0.0803  |0.205   |1.31|6     |1.0e-07              |4.4e-10             |3.472222222222222E-05|
#
# **Soil type 20**
#
# |thetaS |thetaR |thetaWP |thetaFC |n   |alpha |alphaSpecificStorage |betaSpecificStorage |Ks                   |molecularDiffusion |longitudinalDispersivity |
# |-------|-------|--------|--------|----|------|---------------------|--------------------|---------------------|-------------------|-------------------------|
# |0.3    |0.05   |0.0803  |0.22    |1.31|6     |1.0e-07              |4.4e-10             |3.472222222222222E-05|
#
# - etaR = -2.0
# NB: Per creare la griglia necessitiamo delle info delle radici ma queste non vengono usate.
# - water_ponding_0 = -1.4
# - T_water_ponding_0 = 293.15
#
#
# Notebook grid creation name: 06_GEOSPACE1D_SpikeII_Soil_Computational_grid.ipynb
#
# **Evaporation parameters**
#
# |Quantity\Variable  | Unit   | Input                    |
# |-------------------|--------|--------------------------|
# |useWaterStress     | [-]    |true                      |
# |etaE               | [m]    |-1.0                      |
# |representativeModel| [-]    |AverageWaterWeightedMethod|
#
# - Top boundary condition: Top dirichlet
# - Bottom boundary condition : Bottom Free Dreinage
# - Radiation input from GEOframe (NetSpike_1.csv)
#
# ---
# Java file test name: TestGEOSPACE_SpikeSoilEvaporation.java
